# %%
from datasets import load_dataset

ds = load_dataset("Marqo/marqo-GS-10M")
# Out:
# README.md:   0%|          | 0.00/15.8k [00:00<?, ?B/s]
# c:\Users\ellis\AppData\Local\pypoetry\Cache\virtualenvs\shoptalk-py3-12-gEf-GUYK-py3.12\Lib\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\ellis\.cache\huggingface\hub\datasets--Marqo--marqo-GS-10M. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
# ...

# %%
import pandas as pd

# %%
df = pd.read_pickle('../../ABO_dataset/abo-category-check-comp-2.pkl')

# %%
df_dict = df.to_dict(orient='list')
df_dict['image_id'] = df.to_dict(orient='split')['index']

# %%
df_dict.keys()
# Out:
# dict_keys(['item_id', 'product_type', 'match', 'image_id'])

# %%
len(df['item_id'].unique())
# Out:
# 15001

# %%
df_dict.keys()
# Out:
# dict_keys(['item_id', 'product_type', 'match', 'image_id'])

# %%
df_dict['columns']
# Out:
# ['item_id', 'product_type', 'match']

# %%
df_dict['data']
# Out:
# [['B0857LSVB7', 'CELLULAR PHONE CASE', 'Yes'],
#  ['B0857LSVB7', 'CELLULAR PHONE CASE', 'Yes'],
#  ['B0857LSVB7', 'CELLULAR PHONE CASE', 'Yes'],
#  ['B07C5FF8QS', 'AUTO OIL', 'Yes'],
#  ['B07C5FF8QS', 'AUTO OIL', 'Yes'],
#  ['B07C5FF8QS', 'AUTO OIL', 'Yes'],
#  ['B07TG425LX', 'CELLULAR PHONE CASE', 'Yes'],
#  ['B07TG425LX', 'CELLULAR PHONE CASE', 'Yes'],
#  ['B07TG425LX', 'CELLULAR PHONE CASE', 'Yes'],
#  ['B07TG425LX', 'CELLULAR PHONE CASE', 'Yes'],
#  ['B07TG425LX', 'CELLULAR PHONE CASE', 'Yes'],
#  ['B07LCHFZCW', 'GROCERY', 'Yes'],
#  ['B07LCHFZCW', 'GROCERY', 'Yes'],
#  ['B07LCHFZCW', 'GROCERY', 'Yes'],
#  ['B077W2YX72', 'GROCERY', 'Yes'],
#  ['B077W2YX72', 'GROCERY', 'Yes'],
#  ['B077W2YX72', 'GROCERY', 'Yes'],
#  ['B077W2YX72', 'GROCERY', 'Yes'],
#  ['B077W2YX72', 'GROCERY', 'Yes'],
#  ['B07TH39LDF', 'CELLULAR PHONE CASE', 'Yes'],
#  ['B07TH39LDF', 'CELLULAR PHONE CASE', 'Yes'],
#  ['B07TH39LDF', 'CELLULAR PHONE CASE', 'Yes'],
#  ['B07TH39LDF', 'CELLULAR PHONE CASE', 'Yes'],
# ...
